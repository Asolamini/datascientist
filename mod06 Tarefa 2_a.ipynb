# %% [markdown]
# # Módulo 06 Tarefa 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_sinasc = pd.read_csv('b1abb33c4f.csv')

df_sinasc.head(5)
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 1        2        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 2        3        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 3        4        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia
# 4        5        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
#
#    munResLat munResLon  munResAlt  munResArea
# 0  -11.93554 -61.99982      338.0    7067.025
# 1  -11.93554 -61.99982      338.0    7067.025
# 2  -11.93554 -61.99982      338.0    7067.025
# 3  -12.13178 -61.85308      397.0    3958.273
# 4  -11.93554 -61.99982      338.0    7067.025
#
# [5 rows x 69 columns]

# %%
df_sinasc.describe().round(2)
# Out:
#         ORIGEM    CODESTAB  CODMUNNASC   LOCNASC  IDADEMAE  ESTCIVMAE  \
# count  27028.0    26913.00    27028.00  27028.00  27028.00   26711.00
# mean       1.0  3267628.73   111037.80      1.01     26.09       2.55
# std        0.0  1122677.50    18102.75      0.16      6.39       1.67
# min        1.0    15318.00   110001.00      1.00     11.00       1.00
# 25%        1.0  2496534.00   110011.00      1.00     21.00       1.00
# 50%        1.0  2798484.00   110020.00      1.00     26.00       2.00
# 75%        1.0  3970442.00   110020.00      1.00     31.00       5.00
# max        1.0  9659366.00   520870.00      4.00     53.00       9.00
#
#        CODOCUPMAE  QTDFILVIVO  QTDFILMORT  CODMUNRES  ...  STDNNOVA  \
# count    24121.00    25455.00    24930.00   27028.00  ...  27028.00
# mean    795604.03        1.05        0.27  110029.06  ...      1.00
# std     283884.96        1.17        0.61      36.04  ...      0.01
# min      10205.00        0.00        0.00  110000.00  ...      0.00
# 25%     521125.00        0.00        0.00  110012.00  ...      1.00
# 50%     999992.00        1.00        0.00  110020.00  ...      1.00
# 75%     999992.00        2.00        0.00  110028.00  ...      1.00
# max     999994.00       30.00       28.00  110180.00  ...      1.00
#
#        CODPAISRES  TPROBSON  PARIDADE  KOTELCHUCK    CONTADOR  munResLat  \
# count     27028.0  27028.00  27028.00    27028.00    27028.00   27027.00
# mean          1.0      4.33      0.65        4.97   736764.98     -10.38
# std           0.0      2.93      0.48        2.07   743032.48       1.37
# min           1.0      1.00      0.00        1.00        1.00     -13.50
# 25%           1.0      2.00      0.00        4.00     6802.75     -11.43
# 50%           1.0      4.00      1.00        5.00    13645.50     -10.44
# 75%           1.0      5.00      1.00        5.00  1486846.25      -8.77
# max           1.0     11.00      1.00        9.00  2780269.00      -8.77
#
#        munResLon  munResAlt  munResArea
# count   27027.00   27027.00    27027.00
# mean      -62.75     179.11    14702.80
# std         1.27     123.14    13706.18
# min       -65.33      85.00      459.98
# 25%       -63.83      87.00     3793.00
# 50%       -63.03     153.00     6896.65
# 75%       -61.95     191.00    34096.39
# max       -60.14     595.00    34096.39
#
# [8 rows x 54 columns]

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
df_sinasc[['IDADEMAE']].boxplot()

plt.show()

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
df_sinasc[['PESO']].boxplot()

plt.show()

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
df_sinasc['IDADEMAE'].plot.hist(bins = 20)

plt.show()

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
df_sinasc['PESO'].plot.hist(bins = 20)

plt.show()
